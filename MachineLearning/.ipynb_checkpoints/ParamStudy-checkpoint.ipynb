# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import timeit

# %%
target_dict={90:'SNIa',67:'SNIa-91bg',
             52:'SNIax',42:'SNII',
             62:'SNIbc',95:'SLSN-I',
             15:'TDE',64:'KN',
             88:'AGN',92:'RRL',
             65:'M-dwarf',16:'EB',
             53:'Mira',6:'Lens-Single',
             994:'PISN', 999:'UNKNOWN', 1:'NON PISN'}
passband_list = {0:'u',1:'g',2:'r',3:'i',4:'z',5:'y'}

# %% [markdown]
# ## Polynomial model

# %%
path="../FirstFeatureExtraction/Models/tiny_polyDB_complete.pkl"
data=pd.read_pickle(path)
data
# Out:
#       object_id  target         0           1              2         3  \
# 0           745      90  0.024734  -22.012846    4897.324696  0.016554
# 1          1920      90 -0.017271   13.493650   -2487.505350 -0.030588
# 2          2103      42 -0.112749  108.223919  -25838.238579 -0.059112
# 3          2922      67  0.033929  -31.266551    7197.116313  0.059100
# 4          3285      42 -0.200921  333.185214 -138007.012256 -0.151689
# ...         ...     ...       ...         ...            ...       ...
# 1075  128698604     994 -0.009068    2.579725      -5.822678 -0.001624
# 1076  129459600     994 -0.007979   12.561572   -4870.659734 -0.012604
# 1077  129568338     994 -0.002111    1.132741     -22.015479 -0.002590
# 1078  129628489     994  0.000400   -0.493899     111.504145 -0.001100
# 1079  130250777     994 -0.003493    2.450838    -255.280608 -0.004688
#
#                4              5         6           7              8  \
# 0     -15.281943    3539.926816  0.014781  -13.706872    3189.952834
# 1      25.580169   -5199.735582 -0.027598   23.173115   -4733.835313
# 2      56.768146  -13507.794423 -0.103283   99.724482  -23941.247040
# 3     -54.303030   12452.679307  0.053496  -49.424027   11406.693241
# 4     252.243019 -104754.696362 -0.171173  284.702779 -118267.393132
# ...          ...            ...       ...         ...            ...
# 1075    0.682325      11.519542 -0.014950    6.287869    -345.496372
# 1076   19.893440   -7716.334629 -0.013993   22.390235   -8781.828579
# 1077    1.746353    -103.641668 -0.003295    2.466173    -236.534502
# 1078   -0.214648     182.478701 -0.003063    0.479849     191.419240
# 1079    4.329255    -733.661209 -0.008002    8.524838   -1891.479214
#
#              9          10             11
# 0     0.007986   -7.952650    1958.362389
# 1     0.008193   -8.563964    2258.149992
# 2    -0.135939  130.514593  -31197.662827
# 3     0.102135  -88.116862   19027.586668
# 4    -0.195051  324.481430 -134832.225154
# ...        ...         ...            ...
# 1075 -0.003550    1.274033     156.553170
# 1076 -0.025082   40.143602  -15830.330827
# 1077 -0.002599    1.811352     -71.935619
# 1078 -0.002285    0.289236     217.705966
# 1079 -0.006315    6.663130   -1365.309460
#
# [1080 rows x 14 columns]

# %%
data=pd.read_pickle(path)

data.loc[data['target']!=994,'target']=1#BINARY

A_table=data.loc[:,['object_id','target',0]].rename(columns={0: "A"})
B_table=data.loc[:,['object_id','target',1]].rename(columns={1: "B"})
C_table=data.loc[:,['object_id','target',2]].rename(columns={2: "C"})

for i in range(3):
    A_table=A_table.append(data.loc[:,['object_id','target',3*(i+1)]].rename(columns={3*(i+1): "A"}))
    B_table=B_table.append(data.loc[:,['object_id','target',1+3*(i+1)]].rename(columns={1+3*(i+1): "B"}))
    C_table=C_table.append(data.loc[:,['object_id','target',2+3*(i+1)]].rename(columns={2+3*(i+1): "C"})) 
    
A_table
# Out:
#       object_id  target         A
# 0           745       1  0.024734
# 1          1920       1 -0.017271
# 2          2103       1 -0.112749
# 3          2922       1  0.033929
# 4          3285       1 -0.200921
# ...         ...     ...       ...
# 1075  128698604     994 -0.003550
# 1076  129459600     994 -0.025082
# 1077  129568338     994 -0.002599
# 1078  129628489     994 -0.002285
# 1079  130250777     994 -0.006315
#
# [4320 rows x 3 columns]

# %%
targets=np.unique(A_table['target'])





plt.figure(figsize=(17,5))
plt.suptitle('Parameter space',fontsize=18)


ax1 = plt.subplot(1,3,1)

for i in targets:
    
    plt.scatter(A_table.loc[A_table['target']==1,'A'],B_table.loc[B_table['target']==1,'B'],marker='.',label=target_dict.get(i))
    plt.xlabel('A',fontsize=14)
    plt.ylabel('B',fontsize=14)
    ax1.set_xlim([-0.5, 0.25])
    ax1.set_ylim([-400,800])
    plt.legend()


ax2 = plt.subplot(1,3,2)

for i in targets:
    

    plt.scatter(B_table.loc[B_table['target']==i,'B'],C_table.loc[C_table['target']==i,'C'],marker='.',label=target_dict.get(i))
    plt.xlabel('B',fontsize=14)
    plt.ylabel('C',fontsize=14)
    ax2.set_xlim([-400,800])
    ax2.set_ylim([-200000, 70000])
    plt.legend()

    
ax3 = plt.subplot(1,3,3)

for i in targets:    

    
    plt.scatter(C_table.loc[C_table['target']==i,'C'],A_table.loc[A_table['target']==i,'A'],marker='.',label=target_dict.get(i))
    plt.xlabel('C',fontsize=14)
    plt.ylabel('A',fontsize=14)
    ax3.set_xlim([-200000, 70000])
    ax3.set_ylim([-0.5, 0.25])
    plt.legend()

# %%
plt.figure(figsize=(15,8));

band=4                                 # <------------
nb_param=3                             # <------------

x = np.linspace(-5000,5000,100)
plt.title('Distribution of the parameters in passband %s'%(passband_list.get(band)),fontsize=15)

for i in range(nb_param):
    plt.hist(data.loc[:,i],bins=x,alpha=0.6,label=i);
plt.yscale('log')
plt.legend()

# %%
plt.figure(figsize=(15,8))
plt.subplot(3,1,1)
plt.scatter()
